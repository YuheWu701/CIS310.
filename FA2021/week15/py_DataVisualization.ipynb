# %% [markdown]
# # Yuhe Wu
# # week15 - 2021/11/30 - 2021/12/02
# # Python data visualization - Making informative visualizations (using plots)

# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series,DataFrame

#these are the plotting modules and libraries we will use:
import matplotlib as mpl
import matplotlib.pyplot as plt

# command so that plots appera in the iPython Notebook
# %matplotlib inline

# %%
data = np.arange(5)
print(data)
# Out:
# [0 1 2 3 4]

# %%
plt.plot(data)

# %%
data = np.array([1,2,3,4,2,3,3,4,5,6,7,8,1,1,1,1])
data
# Out:
# array([1, 2, 3, 4, 2, 3, 3, 4, 5, 6, 7, 8, 1, 1, 1, 1])

# %%
plt.plot(data)

# %%
data = randn(20)
df = DataFrame(data)
df
# Out:
#            0
# 0  -0.174589
# 1   0.511997
# 2   1.095966
# 3   0.469076
# 4   0.151483
# 5   1.267285
# 6   0.531467
# 7   1.656203
# 8   2.388429
# 9  -0.506484
# 10  0.285714
# 11 -0.871760
# 12 -1.841947
# 13  0.336592
# 14 -1.266148
# 15  2.194118
# 16 -1.244786
# 17  0.675608
# 18  1.561260
# 19 -0.259788

# %%
plt.plot(df)

# %%
dataset1 = randn(100)
s = Series(dataset1)
s
# Out:
# 0     1.467578
# 1     0.371273
# 2    -0.822101
# 3     0.919939
# 4     0.919721
#         ...
# 95    1.074308
# 96   -1.944912
# 97   -0.656623
# 98    0.805208
# 99    0.089161
# Length: 100, dtype: float64

# %%
plt.plot(s)

# %%
plt.plot(dataset1)

# %%
plt.hist(s)
# Out:
# (array([ 8.,  4., 16., 22., 19., 16.,  8.,  4.,  1.,  2.]),
#  array([-1.94491197, -1.46513828, -0.98536459, -0.5055909 , -0.02581722,
#          0.45395647,  0.93373016,  1.41350385,  1.89327754,  2.37305122,
#          2.85282491]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(s, color='indianred')
# Out:
# (array([ 8.,  4., 16., 22., 19., 16.,  8.,  4.,  1.,  2.]),
#  array([-1.94491197, -1.46513828, -0.98536459, -0.5055909 , -0.02581722,
#          0.45395647,  0.93373016,  1.41350385,  1.89327754,  2.37305122,
#          2.85282491]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(s,color='indianred',alpha=.75,bins=10)
s1 = Series(randn(80))
plt.hist(s1,alpha=.75,bins=10)
# Out:
# (array([ 3.,  7., 11., 18., 12., 13.,  7.,  4.,  4.,  1.]),
#  array([-2.00009761, -1.52764491, -1.05519221, -0.58273951, -0.11028681,
#          0.36216588,  0.83461858,  1.30707128,  1.77952398,  2.25197668,
#          2.72442938]),
#  <a list of 10 Patch objects>)

# %%
# figures and subplots
fig = plt.figure()

# %%
fig = plt.figure(figsize = (2,4), dpi=100)

# %%
fig = plt.figure()
fig.add_subplot(2,2,1)  #add_sbplot(nrows,ncols,index,**kwargs)
fig.add_subplot(2,2,2)
fig.add_subplot(2,2,3)
fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #add_sbplot(nrows,ncols,index,**kwargs)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #add_sbplot(nrows,ncols,index,**kwargs)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(4))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #add_sbplot(nrows,ncols,index,**kwargs)
plt.plot(randn(4))
ax2 = fig.add_subplot(2,2,2)
plt.plot(randn(4))
ax3 = fig.add_subplot(2,2,3)
plt.plot(randn(4))
ax4 = fig.add_subplot(2,2,4)
plt.plot(randn(4))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #add_sbplot(nrows,ncols,index,**kwargs)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.plot(randn(4))
ax2.plot(randn(4))
ax3.plot(randn(4))
ax4.plot(randn(4))

# %%
dataset = randn(50).cumsum()
dataset
# Out:
# array([ 0.71891743, -0.03027488, -0.71237347,  0.59016421,  1.21911671,
#         4.1314592 ,  4.42054772,  5.06779156,  5.56864817,  4.8240576 ,
#         4.55503027,  4.37079691,  5.56942219,  6.71140981,  7.6281251 ,
#         8.32284773,  8.05449447,  8.51098653,  9.27948414,  9.34567664,
#         9.10885454,  8.27533383,  8.81594384,  8.91834919,  9.72871054,
#         8.73458989,  9.67179916,  9.30212902,  8.18534708,  6.67073402,
#         6.01588272,  5.59549769,  5.0983712 ,  4.68588894,  4.2405026 ,
#         4.30631371,  4.26276631,  4.73668335,  5.14494193,  4.85450115,
#         2.90062313,  1.25635482,  3.28353245,  3.70442198,  2.523828  ,
#         2.44894281,  2.210015  ,  3.58840239,  3.74067789,  3.61601939])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)  #add_sbplot(nrows,ncols,index,**kwargs)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax4.plot(dataset,'k--') #k-- is dash line

# %%
#add_axes method
fig = plt.figure()
fig.add_axes((.2,0.1,.4,.4)) #The dimensions [left, bottom, width, height] of the new axes
fig.add_axes((0,0,.4,.4))

# %%
fig = plt.figure()

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4))

# %%
fig1 = plt.figure()
ax1 = fig1.add_axes((0,0,.4,.4))
ax2 = fig1.add_axes((0.25,0.25,.3,.3))

# %%
fig2 = plt.figure()
ax1 = fig2.add_axes((0,0,.4,.4))
ax2 = fig2.add_axes((0,0.7,.4,.4))

# %%
fig3 = plt.figure()
ax1 = fig3.add_subplot(2,1,1)
ax2 = fig3.add_subplot(2,1,2)
plt.plot(dataset,'k--')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(dataset,'k--')

# %%
#plot data inside a subplot
ax1.hist(randn(100), bins=20,color='k',alpha=0.8)
ax2.scatter(np.arange(30),randn(30).cumsum())#ax2.scatter(x,y)
fig

# %%
#colors, Markers, and line styles
plt.plot(4*randn(30),'ko--')

# %%
plt.plot(4*randn(30),color='k', linestyle='dashed',marker='o')

# %%
data = randn(30).cumsum()
data
# Out:
# array([-0.52888349, -0.17062947,  1.36711899,  3.69963362,  3.17382413,
#         3.99684053,  3.9371934 ,  4.67593303,  3.36296928,  2.96362196,
#         1.19449601,  0.54972332, -0.75203511, -1.28161693,  0.0383524 ,
#         1.50824559,  1.65376717,  0.4002618 , -1.40913761, -1.35845606,
#        -1.75601225, -2.58280226, -2.3353847 , -2.67303079, -2.94549048,
#        -1.6163487 ,  0.35380602,  0.69044201, -0.9461097 , -0.16500944])

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#            0
# 0  -0.528883
# 1  -0.170629
# 2   1.367119
# 3   3.699634
# 4   3.173824
# 5   3.996841
# 6   3.937193
# 7   4.675933
# 8   3.362969
# 9   2.963622
# 10  1.194496
# 11  0.549723
# 12 -0.752035
# 13 -1.281617
# 14  0.038352
# 15  1.508246
# 16  1.653767
# 17  0.400262
# 18 -1.409138
# 19 -1.358456
# 20 -1.756012
# 21 -2.582802
# 22 -2.335385
# 23 -2.673031
# 24 -2.945490
# 25 -1.616349
# 26  0.353806
# 27  0.690442
# 28 -0.946110
# 29 -0.165009

# %%
plt.plot(data)

# %%
plt.plot(data,drawstyle='steps-post')

# %%
plt.plot(data,'k--')
plt.plot(data,'k-',drawstyle='steps-post')

# %%
#using labels
plt.plot(data,'k--', label='Dashed-Line')
plt.plot(data,'k-',drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')

# %%
d = {'col1':[1,2,4,3,2,1,6,7,3,9], 'col2':[5,8,9,10,12,8,6,2,8,7]}
df2 = pd.DataFrame(d)
df2
# Out:
#    col1  col2
# 0     1     5
# 1     2     8
# 2     4     9
# 3     3    10
# 4     2    12
# 5     1     8
# 6     6     6
# 7     7     2
# 8     3     8
# 9     9     7

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(df2['col1'],'k.',label='col1')
ax.plot(df2['col2'],'ko--',label='col2')
ax.legend(loc='best')

# %%
#DataFrame plotting
df2['col1'].plot.bar()

# %%
df2['col2'].plot.bar()

# %%
#Ticks,Labels, and Legends
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0,250,500,750,1000])

labels = ax.set_xticklabels(['one','two','three','four','five'], rotation=30, fontsize='small')

ax.set_title('My First Matplotlip Plot with Ticks')

ax.set_xlabel('Stages')
ax.set_ylabel('Values')

fig

# %%
props = {'title': 'My First Matplotlip Plot with Ticks',
        'xlabel':'Stages',
        'ylabel':'Values'}

ax.set(**props)
fig

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='three')

ax.legend(loc='best')

# %%
# saving a figure in an image file
fig.savefig('fig1.png')
