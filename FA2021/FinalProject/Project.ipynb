# %%
#Let's go ahead and start with some imports
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# For time stamps
from datetime import datetime

# Optionally add any modules as you need

# %%
data = pd.read_csv('DC_Properties.csv')

# %%
data.head(20)
# Out:
#     Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0            0       4          0      Warm Cool  Y          2      8      4
# 1            1       3          1  Hot Water Rad  Y          2      9      5
# 2            2       3          1  Hot Water Rad  Y          2      8      5
# 3            3       3          1  Hot Water Rad  Y          2      8      4
# 4            4       3          1      Warm Cool  Y          2      7      3
# 5            5       3          1      Warm Cool  Y          2      5      3
# 6            6       3          1      Warm Cool  Y          1      8      3
# 7            7       3          1  Hot Water Rad  Y          2      9      3
# 8            8       3          1  Hot Water Rad  Y          1     14      5
# 9            9       1          0     Forced Air  Y          1      6      3
# 10          10       2          1     Forced Air  Y          1      5      3
# 11          11       2          1  Hot Water Rad  Y          1      8      3
# 12          12       1          0  Hot Water Rad  N          1      8      4
# 13          13       3          0  Hot Water Rad  Y          4      9      3
# 14          14       3          1     Forced Air  Y          2     11      3
# 15          15       2          1     Forced Air  Y          1      6      2
# 16          16       2          2      Warm Cool  Y          2      8      4
# 17          17       3          1     Forced Air  Y          2      9      4
# 18          18       3          1      Warm Cool  Y          2      9      4
# 19          19       3          1     Forced Air  Y          2      9      4
#
#      AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0   1910     1988  ... -77.040832       Old City 2   040 D Old City 2
# 1   1910     2009  ... -77.040678       Old City 2   040 D Old City 2
# 2   1900     2003  ... -77.040629       Old City 2   040 D Old City 2
# 3   1906     2011  ... -77.040129       Old City 2   040 D Old City 2
# 4   1908     2008  ... -77.039903       Old City 2   040 D Old City 2
# 5   1917     2000  ... -77.039716       Old City 2   040 D Old City 2
# 6   1908     2006  ... -77.039844       Old City 2   040 D Old City 2
# 7   1908     2013  ... -77.040138       Old City 2   040 D Old City 2
# 8   1880     2009  ... -77.033774       Old City 2   040 E Old City 2
# 9   1880     2010  ... -77.033925       Old City 2   040 E Old City 2
# 10  1880     2010  ... -77.033972       Old City 2   040 E Old City 2
# 11  1880     2004  ... -77.034070       Old City 2   040 E Old City 2
# 12  1880     2010  ... -77.034156       Old City 2   040 E Old City 2
# 13  1900     1963  ... -77.034182       Old City 2   040 E Old City 2
# 14  1900     2014  ... -77.034051       Old City 2   040 E Old City 2
# 15  1890     2004  ... -77.033846       Old City 2   040 E Old City 2
# 16  1800     2009  ... -77.033367       Old City 2   040 E Old City 2
# 17  1800     1978  ... -77.033156       Old City 2   040 E Old City 2
# 18  1880     2016  ... -77.033087       Old City 2   040 E Old City 2
# 19  1890     2009  ... -77.032950       Old City 2   040 E Old City 2
#
#     CENSUS_TRACT CENSUS_BLOCK    WARD  SQUARE          X          Y QUADRANT
# 0           4201  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 1           4201  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 2           4201  004201 2006  Ward 2     152 -77.040429  38.914881       NW
# 3           4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
# 4           4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
# 5           4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
# 6           4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
# 7           4201  004201 2005  Ward 2     152 -77.040429  38.914881       NW
# 8           5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 9           5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 10          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 11          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 12          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 13          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 14          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 15          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 16          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 17          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 18          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
# 19          5201  005201 4003  Ward 2     208 -77.033366  38.911716       NW
#
# [20 rows x 47 columns]
